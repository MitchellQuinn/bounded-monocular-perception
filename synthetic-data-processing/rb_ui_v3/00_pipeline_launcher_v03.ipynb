# %% [markdown]
# # Raccoon Ball V3 Pipeline Launcher v0.2
#
# Multi-run orchestration UI for threshold and npy/pack stages with selectable training source images (including threshold debug outputs).

# %%
from pathlib import Path
import sys

def find_repo_root(start: Path | None = None) -> Path:
    candidate = (start or Path.cwd()).resolve()
    if candidate.is_file():
        candidate = candidate.parent
    for current in (candidate, *candidate.parents):
        if (current / "input-images").exists() and (current / "rb_pipeline_v3").exists():
            return current
    raise RuntimeError("Could not locate repository root with input-images/ and rb_pipeline_v3/.")

REPO_ROOT = find_repo_root()
if str(REPO_ROOT) not in sys.path:
    sys.path.insert(0, str(REPO_ROOT))

REPO_ROOT
# Out:
# PosixPath('/home/mitch/development/raccoon-ball/synthetic-data-processing')

# %%
import importlib
import rb_pipeline_v3.widgets as widgets_v3

importlib.reload(widgets_v3)
PipelineLauncherV3 = widgets_v3.PipelineLauncherV3

launcher = PipelineLauncherV3(REPO_ROOT)
launcher.display()
