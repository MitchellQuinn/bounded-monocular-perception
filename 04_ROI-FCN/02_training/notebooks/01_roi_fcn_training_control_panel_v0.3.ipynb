# %% [markdown]
# # 01 ROI-FCN Training Control Panel v0.3
#
# Thin notebook wrapper for the ROI-FCN tmux control panel with fresh-training and resume-training workflows.

# %%
from pathlib import Path
import sys

NOTEBOOK_DIR = Path.cwd().resolve()
TRAINING_ROOT = NOTEBOOK_DIR.parent
SRC_ROOT = TRAINING_ROOT / 'src'
if str(SRC_ROOT) not in sys.path:
    sys.path.insert(0, str(SRC_ROOT))

PYTHON_EXECUTABLE = sys.executable

print(f'training_root={TRAINING_ROOT}')
print(f'python={PYTHON_EXECUTABLE}')
# Out:
# training_root=/home/mitch/development/raccoon-ball/04_ROI-FCN/02_training
# python=/home/mitch/development/raccoon-ball/.venv/bin/python

# %%
from roi_fcn_training_v0_1.control_panel_v0_3 import display_training_control_panel_v03

panel = display_training_control_panel_v03(TRAINING_ROOT, python_executable=PYTHON_EXECUTABLE)
