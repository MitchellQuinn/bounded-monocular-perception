# %% [markdown]
# # 01 ROI FCN Training Control Panel v0.1
#
# Thin notebook launcher for the ROI-FCN training harness.

# %%
from pathlib import Path
import sys

NOTEBOOK_DIR = Path.cwd()
TRAINING_ROOT = NOTEBOOK_DIR.parent
SRC_ROOT = TRAINING_ROOT / 'src'
if str(SRC_ROOT) not in sys.path:
    sys.path.insert(0, str(SRC_ROOT))

from roi_fcn_training_v0_1.control_panel import display_training_control_panel_v01

display_training_control_panel_v01(TRAINING_ROOT)
